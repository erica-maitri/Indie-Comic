# %% [markdown]
# # 🔬 Research Phase 5: Final Changes & Spatial Layout
#
# Passing the now-consistent image through the YOLOv8 Speech Bubble optimizer to resolve spatial collisions.

# %% [markdown]
# ## 🔍 1. Initialize YOLOv8 Optimizer

# %%
from ultimate_comic_pipeline import SpeechBubbleOptimizer
optimizer = SpeechBubbleOptimizer()

# %% [markdown]
# ## 🗣️ 2. Detect Collisions and Shift Layout

# %%
print("YOLOv8 is analyzing the image for 'person' and 'face' bounding boxes.")
print("Calculating negative space. If Intersection over Union (IoU) > 0, text coordinates are shifted outwards.")
